# %% [markdown]
# # Training U-Net
# -- Chang (Chris) Qian

# %% [markdown]
# ## Load packages

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import h5py


from tensorflow import keras
from keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.optimizers import Adam
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, CSVLogger
from keras.initializers import *


os.listdir('.')
# Out:
# ['AFM data 1.h5',
#  'AFM data 2.h5',
#  'Inspection U-Net.ipynb',
#  'tf gpu env.txt',
#  'Training set+validation set.h5',
#  'Traning U-Net.ipynb',
#  'U-Net model_20230923_002.hdf5']

# %%
def addDimension(m):
    temp = np.zeros([m.shape[0],m.shape[1],1])
    temp = np.concatenate((m,temp), axis=2)
    return temp

# %%
dataset_path = 'Training set+validation set.h5'
model_path = 'U-Net model_20240312.hdf5'

num_train = 500
num_val = 20

# %% [markdown]
# ## Load data

# %%
with h5py.File(dataset_path, 'r') as file:
    image_stack = file['/data'][:]
    
image_stack = np.moveaxis(image_stack,1, 3)
image_stack = np.swapaxes(image_stack, 1, 2)
image_stack = np.flip(image_stack, axis=1)

fig, ax = plt.subplots(1,3,figsize=(15,5))
i1 = ax[0].imshow(image_stack[0,:,:,2].clip(0,1))
i2 = ax[1].imshow(image_stack[0,:,:,0])
i3 = ax[2].imshow(image_stack[0,:,:,1])
plt.colorbar(i1, ax=ax[0])
plt.colorbar(i2, ax=ax[1])
plt.colorbar(i3, ax=ax[2])

# %%
label_temp = np.random.permutation(num_train+num_val)
train_label = label_temp[0:num_train]
val_label = label_temp[num_train:num_train+num_val]

# print(train_label.shape)
# print(val_label.shape)

imgs_train = image_stack[train_label,:,:,2].clip(0,1)
imgs_train = np.expand_dims(imgs_train, axis=3)
labels_train = image_stack[train_label,:,:,0:2]
imgs_val = image_stack[val_label,:,:,2].clip(0,1)
imgs_val = np.expand_dims(imgs_val, axis=3)
labels_val = image_stack[val_label,:,:,0:2]

print(imgs_train.shape)
print(labels_train.shape)
print(imgs_val.shape)
print(labels_val.shape)
# Out:
# (500, 128, 128, 1)
# (500, 128, 128, 2)
# (20, 128, 128, 1)
# (20, 128, 128, 2)

# %% [markdown]
# ## Initialize U-Net and start training

# %%
def get_unet():
    inputs = Input((128, 128, 1))
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    # print ("conv1 shape:",conv1.shape)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    # print ("conv1 shape:",conv1.shape)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    # print ("pool1 shape:",pool1.shape)

    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    # print ("conv2 shape:",conv2.shape)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    # print ("conv2 shape:",conv2.shape)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    # print ("pool2 shape:",pool2.shape)

    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    # print ("conv3 shape:",conv3.shape)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    # print ("conv3 shape:",conv3.shape)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    # print ("pool3 shape:",pool3.shape)

    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    drop5 = Dropout(0.5)(conv5)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6],axis=3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)

    conv91 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv91 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv91)
    conv91 = Conv2D(9, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv91)

    conv92 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv92 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv92)
    conv92 = Conv2D(9, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv92)

    merge10 = concatenate([conv91,conv92], axis = 3)
    conv10 = Conv2D(2, 1, activation = 'linear')(merge10)

    model = Model(inputs = inputs, outputs = conv10)
    model.compile(optimizer = keras.optimizers.Adam(lr = 1e-4), loss = 'mean_squared_error', metrics = ['accuracy'])
    return model

model = get_unet()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 128)  73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 128)  147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 512)  2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16, 16, 512)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 512)    0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 1024)   4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 1024)   9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8, 8, 1024)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 16, 16, 1024) 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 512)  2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 1024) 0           dropout[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 512)  2359808     conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 512)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 256)  524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 512)  0           conv2d_5[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 256)  0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 128)  131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 256)  0           conv2d_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 128)  295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 128 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 64) 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 128 0           conv2d_1[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 9)  5193        conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 128, 128, 9)  5193        conv2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 18) 0           conv2d_22[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 128, 128, 2)  38          concatenate_4[0][0]
# ==================================================================================================
# Total params: 31,151,672
# Trainable params: 31,151,672
# Non-trainable params: 0
# __________________________________________________________________________________________________
# D:\Anaconda3\envs\tf-gpu\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
model_checkpoint = ModelCheckpoint(model_path, monitor='loss',verbose=1, save_best_only=True)
csv_logger = CSVLogger('log.csv', append=False, separator=',')

print('Fitting model...')
model.fit(imgs_train, labels_train, batch_size=10, epochs=100, verbose=1,validation_split=0.1, shuffle=True, callbacks=[model_checkpoint,csv_logger])
# Out:
# Fitting model...
# Epoch 1/100
# 45/45 [==============================] - 10s 95ms/step - loss: 0.0353 - accuracy: 0.8048 - val_loss: 0.0169 - val_accuracy: 0.9183
#
# Epoch 00001: loss improved from inf to 0.03535, saving model to U-Net model_20240312.hdf5
# Epoch 2/100
# 45/45 [==============================] - 4s 95ms/step - loss: 0.0166 - accuracy: 0.9167 - val_loss: 0.0161 - val_accuracy: 0.9145
#
# Epoch 00002: loss improved from 0.03535 to 0.01662, saving model to U-Net model_20240312.hdf5
# Epoch 3/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0158 - accuracy: 0.9103 - val_loss: 0.0155 - val_accuracy: 0.9131
#
# Epoch 00003: loss improved from 0.01662 to 0.01584, saving model to U-Net model_20240312.hdf5
# Epoch 4/100
# 45/45 [==============================] - 4s 94ms/step - loss: 0.0152 - accuracy: 0.8958 - val_loss: 0.0150 - val_accuracy: 0.9203
#
# Epoch 00004: loss improved from 0.01584 to 0.01517, saving model to U-Net model_20240312.hdf5
# Epoch 5/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0145 - accuracy: 0.8718 - val_loss: 0.0143 - val_accuracy: 0.8367
#
# Epoch 00005: loss improved from 0.01517 to 0.01451, saving model to U-Net model_20240312.hdf5
# Epoch 6/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0140 - accuracy: 0.8488 - val_loss: 0.0138 - val_accuracy: 0.8448
#
# Epoch 00006: loss improved from 0.01451 to 0.01402, saving model to U-Net model_20240312.hdf5
# Epoch 7/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0136 - accuracy: 0.8293 - val_loss: 0.0135 - val_accuracy: 0.8677
#
# Epoch 00007: loss improved from 0.01402 to 0.01362, saving model to U-Net model_20240312.hdf5
# Epoch 8/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0133 - accuracy: 0.8166 - val_loss: 0.0130 - val_accuracy: 0.8089
#
# Epoch 00008: loss improved from 0.01362 to 0.01325, saving model to U-Net model_20240312.hdf5
# Epoch 9/100
# 45/45 [==============================] - 4s 97ms/step - loss: 0.0129 - accuracy: 0.8019 - val_loss: 0.0129 - val_accuracy: 0.7559
#
# Epoch 00009: loss improved from 0.01325 to 0.01292, saving model to U-Net model_20240312.hdf5
# Epoch 10/100
# 45/45 [==============================] - 4s 90ms/step - loss: 0.0126 - accuracy: 0.7889 - val_loss: 0.0124 - val_accuracy: 0.7612
#
# Epoch 00010: loss improved from 0.01292 to 0.01259, saving model to U-Net model_20240312.hdf5
# Epoch 11/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0123 - accuracy: 0.7812 - val_loss: 0.0120 - val_accuracy: 0.7444
#
# Epoch 00011: loss improved from 0.01259 to 0.01225, saving model to U-Net model_20240312.hdf5
# Epoch 12/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0117 - accuracy: 0.7632 - val_loss: 0.0113 - val_accuracy: 0.7489
#
# Epoch 00012: loss improved from 0.01225 to 0.01170, saving model to U-Net model_20240312.hdf5
# Epoch 13/100
# 45/45 [==============================] - 4s 90ms/step - loss: 0.0112 - accuracy: 0.7473 - val_loss: 0.0108 - val_accuracy: 0.7748
#
# Epoch 00013: loss improved from 0.01170 to 0.01117, saving model to U-Net model_20240312.hdf5
# Epoch 14/100
# 45/45 [==============================] - 4s 90ms/step - loss: 0.0105 - accuracy: 0.7310 - val_loss: 0.0100 - val_accuracy: 0.7168
#
# Epoch 00014: loss improved from 0.01117 to 0.01047, saving model to U-Net model_20240312.hdf5
# Epoch 15/100
# 45/45 [==============================] - 4s 90ms/step - loss: 0.0098 - accuracy: 0.7175 - val_loss: 0.0093 - val_accuracy: 0.7192
#
# Epoch 00015: loss improved from 0.01047 to 0.00976, saving model to U-Net model_20240312.hdf5
# Epoch 16/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0091 - accuracy: 0.7022 - val_loss: 0.0087 - val_accuracy: 0.6775
#
# Epoch 00016: loss improved from 0.00976 to 0.00913, saving model to U-Net model_20240312.hdf5
# Epoch 17/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0087 - accuracy: 0.6954 - val_loss: 0.0084 - val_accuracy: 0.6292
#
# Epoch 00017: loss improved from 0.00913 to 0.00870, saving model to U-Net model_20240312.hdf5
# Epoch 18/100
# 45/45 [==============================] - 4s 93ms/step - loss: 0.0086 - accuracy: 0.6994 - val_loss: 0.0082 - val_accuracy: 0.6586
#
# Epoch 00018: loss improved from 0.00870 to 0.00861, saving model to U-Net model_20240312.hdf5
# Epoch 19/100
# 45/45 [==============================] - 4s 93ms/step - loss: 0.0081 - accuracy: 0.6930 - val_loss: 0.0078 - val_accuracy: 0.6913
#
# Epoch 00019: loss improved from 0.00861 to 0.00810, saving model to U-Net model_20240312.hdf5
# Epoch 20/100
# 45/45 [==============================] - 4s 93ms/step - loss: 0.0078 - accuracy: 0.6922 - val_loss: 0.0075 - val_accuracy: 0.8120
#
# Epoch 00020: loss improved from 0.00810 to 0.00784, saving model to U-Net model_20240312.hdf5
# Epoch 21/100
# 45/45 [==============================] - 4s 93ms/step - loss: 0.0075 - accuracy: 0.6918 - val_loss: 0.0073 - val_accuracy: 0.5827
#
# Epoch 00021: loss improved from 0.00784 to 0.00751, saving model to U-Net model_20240312.hdf5
# Epoch 22/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0073 - accuracy: 0.6912 - val_loss: 0.0070 - val_accuracy: 0.5672
#
# Epoch 00022: loss improved from 0.00751 to 0.00730, saving model to U-Net model_20240312.hdf5
# Epoch 23/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0071 - accuracy: 0.6902 - val_loss: 0.0070 - val_accuracy: 0.5493
#
# Epoch 00023: loss improved from 0.00730 to 0.00705, saving model to U-Net model_20240312.hdf5
# Epoch 24/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0068 - accuracy: 0.6859 - val_loss: 0.0068 - val_accuracy: 0.6750
#
# Epoch 00024: loss improved from 0.00705 to 0.00682, saving model to U-Net model_20240312.hdf5
# Epoch 25/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0066 - accuracy: 0.6902 - val_loss: 0.0068 - val_accuracy: 0.7405
#
# Epoch 00025: loss improved from 0.00682 to 0.00661, saving model to U-Net model_20240312.hdf5
# Epoch 26/100
# 45/45 [==============================] - 4s 90ms/step - loss: 0.0066 - accuracy: 0.6909 - val_loss: 0.0065 - val_accuracy: 0.6406
#
# Epoch 00026: loss improved from 0.00661 to 0.00659, saving model to U-Net model_20240312.hdf5
# Epoch 27/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0064 - accuracy: 0.7002 - val_loss: 0.0065 - val_accuracy: 0.6536
#
# Epoch 00027: loss improved from 0.00659 to 0.00636, saving model to U-Net model_20240312.hdf5
# Epoch 28/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0060 - accuracy: 0.6863 - val_loss: 0.0064 - val_accuracy: 0.6873
#
# Epoch 00028: loss improved from 0.00636 to 0.00599, saving model to U-Net model_20240312.hdf5
# Epoch 29/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0058 - accuracy: 0.6927 - val_loss: 0.0065 - val_accuracy: 0.7043
#
# Epoch 00029: loss improved from 0.00599 to 0.00583, saving model to U-Net model_20240312.hdf5
# Epoch 30/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0057 - accuracy: 0.6807 - val_loss: 0.0065 - val_accuracy: 0.8493
#
# Epoch 00030: loss improved from 0.00583 to 0.00573, saving model to U-Net model_20240312.hdf5
# Epoch 31/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0056 - accuracy: 0.6934 - val_loss: 0.0066 - val_accuracy: 0.6843
#
# Epoch 00031: loss improved from 0.00573 to 0.00563, saving model to U-Net model_20240312.hdf5
# Epoch 32/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0052 - accuracy: 0.6898 - val_loss: 0.0065 - val_accuracy: 0.8320
#
# Epoch 00032: loss improved from 0.00563 to 0.00519, saving model to U-Net model_20240312.hdf5
# Epoch 33/100
# 45/45 [==============================] - 4s 94ms/step - loss: 0.0050 - accuracy: 0.6920 - val_loss: 0.0063 - val_accuracy: 0.7463
#
# Epoch 00033: loss improved from 0.00519 to 0.00502, saving model to U-Net model_20240312.hdf5
# Epoch 34/100
# 45/45 [==============================] - 4s 95ms/step - loss: 0.0048 - accuracy: 0.6918 - val_loss: 0.0063 - val_accuracy: 0.7365
#
# Epoch 00034: loss improved from 0.00502 to 0.00478, saving model to U-Net model_20240312.hdf5
# Epoch 35/100
# 45/45 [==============================] - 4s 95ms/step - loss: 0.0046 - accuracy: 0.6867 - val_loss: 0.0062 - val_accuracy: 0.7698
#
# Epoch 00035: loss improved from 0.00478 to 0.00465, saving model to U-Net model_20240312.hdf5
# Epoch 36/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0044 - accuracy: 0.6814 - val_loss: 0.0063 - val_accuracy: 0.8381
#
# Epoch 00036: loss improved from 0.00465 to 0.00445, saving model to U-Net model_20240312.hdf5
# Epoch 37/100
# 45/45 [==============================] - 4s 93ms/step - loss: 0.0042 - accuracy: 0.6925 - val_loss: 0.0066 - val_accuracy: 0.6205
#
# Epoch 00037: loss improved from 0.00445 to 0.00420, saving model to U-Net model_20240312.hdf5
# Epoch 38/100
# 45/45 [==============================] - 4s 93ms/step - loss: 0.0041 - accuracy: 0.6851 - val_loss: 0.0064 - val_accuracy: 0.6465
#
# Epoch 00038: loss improved from 0.00420 to 0.00413, saving model to U-Net model_20240312.hdf5
# Epoch 39/100
# 45/45 [==============================] - 4s 95ms/step - loss: 0.0039 - accuracy: 0.6853 - val_loss: 0.0063 - val_accuracy: 0.6918
#
# Epoch 00039: loss improved from 0.00413 to 0.00390, saving model to U-Net model_20240312.hdf5
# Epoch 40/100
# 45/45 [==============================] - 4s 90ms/step - loss: 0.0038 - accuracy: 0.6889 - val_loss: 0.0066 - val_accuracy: 0.6223
#
# Epoch 00040: loss improved from 0.00390 to 0.00375, saving model to U-Net model_20240312.hdf5
# Epoch 41/100
# 45/45 [==============================] - 4s 90ms/step - loss: 0.0036 - accuracy: 0.6793 - val_loss: 0.0062 - val_accuracy: 0.6949
#
# Epoch 00041: loss improved from 0.00375 to 0.00364, saving model to U-Net model_20240312.hdf5
# Epoch 42/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0035 - accuracy: 0.6896 - val_loss: 0.0065 - val_accuracy: 0.6822
#
# Epoch 00042: loss improved from 0.00364 to 0.00353, saving model to U-Net model_20240312.hdf5
# Epoch 43/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0035 - accuracy: 0.6872 - val_loss: 0.0064 - val_accuracy: 0.7129
#
# Epoch 00043: loss improved from 0.00353 to 0.00348, saving model to U-Net model_20240312.hdf5
# Epoch 44/100
# 45/45 [==============================] - 4s 95ms/step - loss: 0.0034 - accuracy: 0.6903 - val_loss: 0.0063 - val_accuracy: 0.4999
#
# Epoch 00044: loss improved from 0.00348 to 0.00342, saving model to U-Net model_20240312.hdf5
# Epoch 45/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0033 - accuracy: 0.6900 - val_loss: 0.0060 - val_accuracy: 0.6417
#
# Epoch 00045: loss improved from 0.00342 to 0.00330, saving model to U-Net model_20240312.hdf5
# Epoch 46/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0032 - accuracy: 0.6928 - val_loss: 0.0065 - val_accuracy: 0.6567
#
# Epoch 00046: loss improved from 0.00330 to 0.00315, saving model to U-Net model_20240312.hdf5
# Epoch 47/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0031 - accuracy: 0.6855 - val_loss: 0.0062 - val_accuracy: 0.6947
#
# Epoch 00047: loss improved from 0.00315 to 0.00306, saving model to U-Net model_20240312.hdf5
# Epoch 48/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0031 - accuracy: 0.6930 - val_loss: 0.0060 - val_accuracy: 0.7896
#
# Epoch 00048: loss did not improve from 0.00306
# Epoch 49/100
# 45/45 [==============================] - 4s 90ms/step - loss: 0.0030 - accuracy: 0.6911 - val_loss: 0.0062 - val_accuracy: 0.6208
#
# Epoch 00049: loss improved from 0.00306 to 0.00305, saving model to U-Net model_20240312.hdf5
# Epoch 50/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0029 - accuracy: 0.6855 - val_loss: 0.0067 - val_accuracy: 0.8653
#
# Epoch 00050: loss improved from 0.00305 to 0.00294, saving model to U-Net model_20240312.hdf5
# Epoch 51/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0029 - accuracy: 0.6934 - val_loss: 0.0065 - val_accuracy: 0.6272
#
# Epoch 00051: loss improved from 0.00294 to 0.00289, saving model to U-Net model_20240312.hdf5
# Epoch 52/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0028 - accuracy: 0.6887 - val_loss: 0.0062 - val_accuracy: 0.6627
#
# Epoch 00052: loss improved from 0.00289 to 0.00280, saving model to U-Net model_20240312.hdf5
# Epoch 53/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0027 - accuracy: 0.6943 - val_loss: 0.0062 - val_accuracy: 0.7206
#
# Epoch 00053: loss improved from 0.00280 to 0.00275, saving model to U-Net model_20240312.hdf5
# Epoch 54/100
# 45/45 [==============================] - 4s 90ms/step - loss: 0.0026 - accuracy: 0.6901 - val_loss: 0.0060 - val_accuracy: 0.7458
#
# Epoch 00054: loss improved from 0.00275 to 0.00263, saving model to U-Net model_20240312.hdf5
# Epoch 55/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0026 - accuracy: 0.6938 - val_loss: 0.0064 - val_accuracy: 0.7004
#
# Epoch 00055: loss improved from 0.00263 to 0.00259, saving model to U-Net model_20240312.hdf5
# Epoch 56/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0026 - accuracy: 0.6918 - val_loss: 0.0059 - val_accuracy: 0.6627
#
# Epoch 00056: loss did not improve from 0.00259
# Epoch 57/100
# 45/45 [==============================] - 4s 94ms/step - loss: 0.0026 - accuracy: 0.6952 - val_loss: 0.0062 - val_accuracy: 0.6195
#
# Epoch 00057: loss improved from 0.00259 to 0.00255, saving model to U-Net model_20240312.hdf5
# Epoch 58/100
# 45/45 [==============================] - 4s 93ms/step - loss: 0.0025 - accuracy: 0.6893 - val_loss: 0.0065 - val_accuracy: 0.6667
#
# Epoch 00058: loss improved from 0.00255 to 0.00251, saving model to U-Net model_20240312.hdf5
# Epoch 59/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0025 - accuracy: 0.6924 - val_loss: 0.0063 - val_accuracy: 0.6069
#
# Epoch 00059: loss improved from 0.00251 to 0.00250, saving model to U-Net model_20240312.hdf5
# Epoch 60/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0024 - accuracy: 0.6947 - val_loss: 0.0059 - val_accuracy: 0.7583
#
# Epoch 00060: loss improved from 0.00250 to 0.00238, saving model to U-Net model_20240312.hdf5
# Epoch 61/100
# 45/45 [==============================] - 4s 94ms/step - loss: 0.0023 - accuracy: 0.6912 - val_loss: 0.0066 - val_accuracy: 0.8203
#
# Epoch 00061: loss improved from 0.00238 to 0.00235, saving model to U-Net model_20240312.hdf5
# Epoch 62/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0024 - accuracy: 0.6918 - val_loss: 0.0061 - val_accuracy: 0.6713
#
# Epoch 00062: loss did not improve from 0.00235
# Epoch 63/100
# 45/45 [==============================] - 4s 94ms/step - loss: 0.0023 - accuracy: 0.6945 - val_loss: 0.0065 - val_accuracy: 0.7821
#
# Epoch 00063: loss improved from 0.00235 to 0.00233, saving model to U-Net model_20240312.hdf5
# Epoch 64/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0023 - accuracy: 0.6944 - val_loss: 0.0064 - val_accuracy: 0.7211
#
# Epoch 00064: loss improved from 0.00233 to 0.00226, saving model to U-Net model_20240312.hdf5
# Epoch 65/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0022 - accuracy: 0.6896 - val_loss: 0.0062 - val_accuracy: 0.7755
#
# Epoch 00065: loss improved from 0.00226 to 0.00224, saving model to U-Net model_20240312.hdf5
# Epoch 66/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0022 - accuracy: 0.6910 - val_loss: 0.0063 - val_accuracy: 0.7084
#
# Epoch 00066: loss improved from 0.00224 to 0.00218, saving model to U-Net model_20240312.hdf5
# Epoch 67/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0021 - accuracy: 0.6962 - val_loss: 0.0060 - val_accuracy: 0.6473
#
# Epoch 00067: loss improved from 0.00218 to 0.00209, saving model to U-Net model_20240312.hdf5
# Epoch 68/100
# 45/45 [==============================] - 4s 90ms/step - loss: 0.0021 - accuracy: 0.6874 - val_loss: 0.0062 - val_accuracy: 0.7531
#
# Epoch 00068: loss did not improve from 0.00209
# Epoch 69/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0021 - accuracy: 0.6967 - val_loss: 0.0061 - val_accuracy: 0.6981
#
# Epoch 00069: loss improved from 0.00209 to 0.00206, saving model to U-Net model_20240312.hdf5
# Epoch 70/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0025 - accuracy: 0.6904 - val_loss: 0.0063 - val_accuracy: 0.6260
#
# Epoch 00070: loss did not improve from 0.00206
# Epoch 71/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0023 - accuracy: 0.6879 - val_loss: 0.0065 - val_accuracy: 0.7465
#
# Epoch 00071: loss did not improve from 0.00206
# Epoch 72/100
# 45/45 [==============================] - 4s 90ms/step - loss: 0.0020 - accuracy: 0.6980 - val_loss: 0.0059 - val_accuracy: 0.6964
#
# Epoch 00072: loss improved from 0.00206 to 0.00204, saving model to U-Net model_20240312.hdf5
# Epoch 73/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0020 - accuracy: 0.6906 - val_loss: 0.0063 - val_accuracy: 0.6136
#
# Epoch 00073: loss improved from 0.00204 to 0.00202, saving model to U-Net model_20240312.hdf5
# Epoch 74/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0018 - accuracy: 0.6888 - val_loss: 0.0061 - val_accuracy: 0.7157
#
# Epoch 00074: loss improved from 0.00202 to 0.00181, saving model to U-Net model_20240312.hdf5
# Epoch 75/100
# 45/45 [==============================] - 4s 94ms/step - loss: 0.0017 - accuracy: 0.6906 - val_loss: 0.0059 - val_accuracy: 0.7330
#
# Epoch 00075: loss improved from 0.00181 to 0.00172, saving model to U-Net model_20240312.hdf5
# Epoch 76/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0017 - accuracy: 0.6918 - val_loss: 0.0060 - val_accuracy: 0.6530
#
# Epoch 00076: loss improved from 0.00172 to 0.00171, saving model to U-Net model_20240312.hdf5
# Epoch 77/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0017 - accuracy: 0.6917 - val_loss: 0.0062 - val_accuracy: 0.7680
#
# Epoch 00077: loss improved from 0.00171 to 0.00170, saving model to U-Net model_20240312.hdf5
# Epoch 78/100
# 45/45 [==============================] - 4s 95ms/step - loss: 0.0016 - accuracy: 0.6872 - val_loss: 0.0059 - val_accuracy: 0.6638
#
# Epoch 00078: loss improved from 0.00170 to 0.00161, saving model to U-Net model_20240312.hdf5
# Epoch 79/100
# 45/45 [==============================] - 4s 96ms/step - loss: 0.0016 - accuracy: 0.6907 - val_loss: 0.0061 - val_accuracy: 0.7134
#
# Epoch 00079: loss improved from 0.00161 to 0.00156, saving model to U-Net model_20240312.hdf5
# Epoch 80/100
# 45/45 [==============================] - 4s 93ms/step - loss: 0.0015 - accuracy: 0.6947 - val_loss: 0.0063 - val_accuracy: 0.7866
#
# Epoch 00080: loss improved from 0.00156 to 0.00153, saving model to U-Net model_20240312.hdf5
# Epoch 81/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0015 - accuracy: 0.6899 - val_loss: 0.0061 - val_accuracy: 0.7139
#
# Epoch 00081: loss improved from 0.00153 to 0.00151, saving model to U-Net model_20240312.hdf5
# Epoch 82/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0015 - accuracy: 0.6914 - val_loss: 0.0061 - val_accuracy: 0.6825
#
# Epoch 00082: loss improved from 0.00151 to 0.00148, saving model to U-Net model_20240312.hdf5
# Epoch 83/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0015 - accuracy: 0.6929 - val_loss: 0.0060 - val_accuracy: 0.6969
#
# Epoch 00083: loss improved from 0.00148 to 0.00146, saving model to U-Net model_20240312.hdf5
# Epoch 84/100
# 45/45 [==============================] - 4s 94ms/step - loss: 0.0015 - accuracy: 0.6929 - val_loss: 0.0058 - val_accuracy: 0.7068
#
# Epoch 00084: loss did not improve from 0.00146
# Epoch 85/100
# 45/45 [==============================] - 4s 93ms/step - loss: 0.0015 - accuracy: 0.6908 - val_loss: 0.0061 - val_accuracy: 0.7369
#
# Epoch 00085: loss improved from 0.00146 to 0.00145, saving model to U-Net model_20240312.hdf5
# Epoch 86/100
# 45/45 [==============================] - 4s 93ms/step - loss: 0.0014 - accuracy: 0.6940 - val_loss: 0.0061 - val_accuracy: 0.6818
#
# Epoch 00086: loss improved from 0.00145 to 0.00141, saving model to U-Net model_20240312.hdf5
# Epoch 87/100
# 45/45 [==============================] - 4s 93ms/step - loss: 0.0015 - accuracy: 0.6923 - val_loss: 0.0061 - val_accuracy: 0.6494
#
# Epoch 00087: loss did not improve from 0.00141
# Epoch 88/100
# 45/45 [==============================] - 4s 93ms/step - loss: 0.0014 - accuracy: 0.6925 - val_loss: 0.0057 - val_accuracy: 0.7262
#
# Epoch 00088: loss did not improve from 0.00141
# Epoch 89/100
# 45/45 [==============================] - 4s 94ms/step - loss: 0.0013 - accuracy: 0.6911 - val_loss: 0.0060 - val_accuracy: 0.7396
#
# Epoch 00089: loss improved from 0.00141 to 0.00134, saving model to U-Net model_20240312.hdf5
# Epoch 90/100
# 45/45 [==============================] - 4s 94ms/step - loss: 0.0014 - accuracy: 0.6961 - val_loss: 0.0060 - val_accuracy: 0.6854
#
# Epoch 00090: loss did not improve from 0.00134
# Epoch 91/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0013 - accuracy: 0.6973 - val_loss: 0.0058 - val_accuracy: 0.6401
#
# Epoch 00091: loss did not improve from 0.00134
# Epoch 92/100
# 45/45 [==============================] - 4s 93ms/step - loss: 0.0013 - accuracy: 0.6914 - val_loss: 0.0060 - val_accuracy: 0.6975
#
# Epoch 00092: loss improved from 0.00134 to 0.00130, saving model to U-Net model_20240312.hdf5
# Epoch 93/100
# 45/45 [==============================] - 4s 93ms/step - loss: 0.0013 - accuracy: 0.6954 - val_loss: 0.0061 - val_accuracy: 0.6220
#
# Epoch 00093: loss improved from 0.00130 to 0.00129, saving model to U-Net model_20240312.hdf5
# Epoch 94/100
# 45/45 [==============================] - 4s 96ms/step - loss: 0.0012 - accuracy: 0.6924 - val_loss: 0.0059 - val_accuracy: 0.6924
#
# Epoch 00094: loss improved from 0.00129 to 0.00123, saving model to U-Net model_20240312.hdf5
# Epoch 95/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0012 - accuracy: 0.6966 - val_loss: 0.0058 - val_accuracy: 0.7319
#
# Epoch 00095: loss improved from 0.00123 to 0.00121, saving model to U-Net model_20240312.hdf5
# Epoch 96/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0012 - accuracy: 0.6958 - val_loss: 0.0059 - val_accuracy: 0.5673
#
# Epoch 00096: loss improved from 0.00121 to 0.00120, saving model to U-Net model_20240312.hdf5
# Epoch 97/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0013 - accuracy: 0.6921 - val_loss: 0.0061 - val_accuracy: 0.7020
#
# Epoch 00097: loss did not improve from 0.00120
# Epoch 98/100
# 45/45 [==============================] - 4s 92ms/step - loss: 0.0012 - accuracy: 0.6917 - val_loss: 0.0057 - val_accuracy: 0.7314
#
# Epoch 00098: loss improved from 0.00120 to 0.00119, saving model to U-Net model_20240312.hdf5
# Epoch 99/100
# 45/45 [==============================] - 4s 93ms/step - loss: 0.0012 - accuracy: 0.6952 - val_loss: 0.0059 - val_accuracy: 0.6745
#
# Epoch 00099: loss improved from 0.00119 to 0.00119, saving model to U-Net model_20240312.hdf5
# Epoch 100/100
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0012 - accuracy: 0.6986 - val_loss: 0.0059 - val_accuracy: 0.7352
#
# Epoch 00100: loss improved from 0.00119 to 0.00118, saving model to U-Net model_20240312.hdf5

# %% [markdown]
# ## Prediction on validation set

# %%
predictions_val = model.predict(imgs_val, batch_size=1, verbose=1)
# Out:
# 20/20 [==============================] - 1s 8ms/step

# %%
predictions_val.shape
# Out:
# (20, 128, 128, 2)

# %%
num_plot = 3
inds = np.random.permutation(imgs_val.shape[0])

fig, axs = plt.subplots(num_plot,3,figsize=(20,20/3*num_plot))
fig.set_tight_layout(True)

for idx in range(num_plot):
    i = inds[idx]
    axs[idx,0].imshow(imgs_val[i])
    axs[idx,1].imshow(addDimension(predictions_val[i]))
    axs[idx,2].imshow(addDimension(labels_val[i]))
    axs[idx,0].axis('off')
    axs[idx,1].axis('off')
    axs[idx,2].axis('off')
    
axs[0,0].set_title('train')
axs[0,1].set_title('prediction')
axs[0,2].set_title('ground truth')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'ground truth')

# %%
output_path = 'prediction_validation_20240312.h5'
temp = np.concatenate((imgs_val,predictions_val), axis=3)

import h5py
import numpy as np
with h5py.File(output_path, 'w') as file:
    file.create_dataset('data', data=temp)

temp.shape
# Out:
# (20, 128, 128, 3)
